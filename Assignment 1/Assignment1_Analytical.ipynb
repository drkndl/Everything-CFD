# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = 0.5
nx = 10
xarr = np.linspace(0,x,nx)
print(xarr)
# Out:
# [0.         0.05555556 0.11111111 0.16666667 0.22222222 0.27777778
#  0.33333333 0.38888889 0.44444444 0.5       ]

# %%
yarr = 629.756*xarr - 50000*xarr**2/41
print(yarr)
# Out:
# [ 0.         31.22251792 54.91718278 71.08399458 79.72295333 80.83405902
#  74.41731165 60.47271123 39.00025775  9.99995122]

# %%
plt.plot(xarr, yarr)
